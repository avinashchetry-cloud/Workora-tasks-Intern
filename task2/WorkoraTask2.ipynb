# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/netflix_customer_churn.csv')
df.sample(5)
# Out:
#                                customer_id  age  gender subscription_type  \
# 208   dae2da1f-76cb-41c0-b04f-33dc860fcf32   34    Male           Premium
# 137   844f2522-32e3-4f44-a960-cd0c13881618   45   Other             Basic
# 1999  47366ae4-467f-4bec-b49d-a7f22b794f59   62   Other           Premium
# 3399  b58920d7-b06e-4602-8f17-6351acee76bb   33  Female          Standard
# 3263  bdeb4f47-097c-49b8-956a-d9fa25802324   21   Other           Premium
#
#       watch_hours  last_login_days         region   device  monthly_fee  \
# 208         70.61               38        Oceania       TV        17.99
# 137          3.40               27  North America   Laptop         8.99
# 1999         5.98               48  North America   Tablet        17.99
# 3399        32.18               29  South America  Desktop        13.99
# 3263         6.27               53  North America  Desktop        17.99
#
#       churned payment_method  number_of_profiles  avg_watch_time_per_day  \
# ...

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'subscription_type', 'watch_hours',
#        'last_login_days', 'region', 'device', 'monthly_fee', 'churned',
#        'payment_method', 'number_of_profiles', 'avg_watch_time_per_day',
#        'favorite_genre'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             5000 non-null   object
#  1   age                     5000 non-null   int64
#  2   gender                  5000 non-null   object
#  3   subscription_type       5000 non-null   object
#  4   watch_hours             5000 non-null   float64
#  5   last_login_days         5000 non-null   int64
#  6   region                  5000 non-null   object
#  7   device                  5000 non-null   object
#  8   monthly_fee             5000 non-null   float64
#  9   churned                 5000 non-null   int64
#  10  payment_method          5000 non-null   object
#  11  number_of_profiles      5000 non-null   int64
#  12  avg_watch_time_per_day  5000 non-null   float64
#  13  favorite_genre          5000 non-null   object
# ...

# %%
df.describe()
# Out:
#                age  watch_hours  last_login_days  monthly_fee      churned  \
# count  5000.000000  5000.000000      5000.000000  5000.000000  5000.000000
# mean     43.847400    11.649450        30.089800    13.683400     0.503000
# std      15.501128    12.014654        17.536078     3.692062     0.500041
# min      18.000000     0.010000         0.000000     8.990000     0.000000
# 25%      30.000000     3.337500        15.000000     8.990000     0.000000
# 50%      44.000000     8.000000        30.000000    13.990000     1.000000
# 75%      58.000000    16.030000        45.000000    17.990000     1.000000
# max      70.000000   110.400000        60.000000    17.990000     1.000000
#
#        number_of_profiles  avg_watch_time_per_day
# count         5000.000000             5000.000000
# mean             3.024400                0.874800
# std              1.415841                2.619824
# min              1.000000                0.000000
# ...

# %%
df.dtypes
# Out:
# customer_id                object
# age                         int64
# gender                     object
# subscription_type          object
# watch_hours               float64
# last_login_days             int64
# region                     object
# device                     object
# monthly_fee               float64
# churned                     int64
# payment_method             object
# number_of_profiles          int64
# avg_watch_time_per_day    float64
# favorite_genre             object
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# customer_id               0
# age                       0
# gender                    0
# subscription_type         0
# watch_hours               0
# last_login_days           0
# region                    0
# device                    0
# monthly_fee               0
# churned                   0
# payment_method            0
# number_of_profiles        0
# avg_watch_time_per_day    0
# favorite_genre            0
# dtype: int64

# %%
df.head()
# Out:
#                             customer_id  age  gender subscription_type  \
# 0  a9b75100-82a8-427a-a208-72f24052884a   51   Other             Basic
# 1  49a5dfd9-7e69-4022-a6ad-0a1b9767fb5b   47   Other          Standard
# 2  4d71f6ce-fca9-4ff7-8afa-197ac24de14b   27  Female          Standard
# 3  d3c72c38-631b-4f9e-8a0e-de103cad1a7d   53   Other           Premium
# 4  4e265c34-103a-4dbb-9553-76c9aa47e946   56   Other          Standard
#
#    watch_hours  last_login_days   region  device  monthly_fee  churned  \
# 0        14.73               29   Africa      TV         8.99        1
# 1         0.70               19   Europe  Mobile        13.99        1
# 2        16.32               10     Asia      TV        13.99        0
# 3         4.51               12  Oceania      TV        17.99        1
# 4         1.89               13   Africa  Mobile        13.99        1
#
#   payment_method  number_of_profiles  avg_watch_time_per_day favorite_genre
# ...

# %%
cols = df.columns.drop('customer_id').tolist()
cols
# Out:
# ['age',
#  'gender',
#  'subscription_type',
#  'watch_hours',
#  'last_login_days',
#  'region',
#  'device',
#  'monthly_fee',
#  'churned',
#  'payment_method',
#  'number_of_profiles',
#  'avg_watch_time_per_day',
#  'favorite_genre']

# %%
df[df['age'] <= 0]
# Out:
# Empty DataFrame
# Columns: [customer_id, age, gender, subscription_type, watch_hours, last_login_days, region, device, monthly_fee, churned, payment_method, number_of_profiles, avg_watch_time_per_day, favorite_genre]
# Index: []

# %%
df[df['watch_hours'] <= 0]
# Out:
# Empty DataFrame
# Columns: [customer_id, age, gender, subscription_type, watch_hours, last_login_days, region, device, monthly_fee, churned, payment_method, number_of_profiles, avg_watch_time_per_day, favorite_genre]
# Index: []

# %%
df[df['monthly_fee'] <= 0]
# Out:
# Empty DataFrame
# Columns: [customer_id, age, gender, subscription_type, watch_hours, last_login_days, region, device, monthly_fee, churned, payment_method, number_of_profiles, avg_watch_time_per_day, favorite_genre]
# Index: []

# %%
churn = df['churned']
churn_counts = churn.value_counts().sort_values()
churn_counts
churn_labels = ['Inactive', 'Active']
churn_val = churn_counts.values

# %%
import matplotlib.pyplot as plt
import seaborn as sns

colors=['#2A9D8F', '#E76F51']
plt.pie(labels=churn_labels, x=churn_val, autopct='%0.2f%%', colors=colors)
plt.title('Churn Rate')
plt.show()

# %%
subscription = df['subscription_type']
subscription_counts = subscription.value_counts().sort_values()
subscription_counts
subscription_labels = ['Standard' ,'Basic', 'Premium']
subscription_val = subscription_counts.values

# %%
import matplotlib.pyplot as plt
import seaborn as sns

colors=['#2A9D8F', '#E76F51', '#4A607A']
plt.pie(labels=subscription_labels, x=subscription_val, autopct='%0.2f%%', colors=colors)
plt.title('Subscription Type Proportion')
plt.show()

# %%
payment = df['payment_method']
payment_counts = payment.value_counts().sort_values()
payment_counts
payment_labels = ['Credit Card' ,'Gift Card', 'Crypto', 'PayPal', 'Debit Card']
payment_val = payment_counts.values

# %%
colors=['#4A607A', '#8FA89B', '#7FE5C4', '#F4A261', '#E7ECEF']
plt.pie(labels=payment_labels, x=payment_val, autopct='%0.2f%%', colors=colors)
plt.title('Payment Type Proportion')
plt.show()

# %%
df['favorite_genre'].nunique()
# Out:
# 7

# %%
df['favorite_genre'].value_counts().sort_values()
# Out:
# favorite_genre
# Comedy         685
# Action         697
# Horror         713
# Sci-Fi         720
# Romance        725
# Documentary    729
# Drama          731
# Name: count, dtype: int64

# %%
genre = df['favorite_genre']
genre_counts = genre.value_counts().sort_values()
genre_counts
genre_labels = ['Comedy' ,'Action', 'Horror', 'Sci-FI', 'Romance', 'Documentary', 'Drama']
genre_val = genre_counts.values

# %%
colors=['#2E5B88', '#4A809C', '#68A6AD', '#9EC8B9', '#F0D8A8', '#EFA885', '#D97D7D']
plt.pie(labels=genre_labels, x=genre_val, autopct='%0.2f%%', colors=colors)
plt.title('Genre Type Proportion')
plt.show()

# %%
colors = ['#2E5B88', '#4A809C', '#68A6AD', '#9EC8B9', '#F0D8A8']
sns.countplot(data=df, x='region', palette=colors)
plt.title("Distribution of Customers Across Regions")
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_2710/3005552588.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='region', palette=colors)
# /tmp/ipykernel_2710/3005552588.py:2: UserWarning:
# The palette list has fewer values (5) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(data=df, x='region', palette=colors)

# %%
colors = ['#2E5B88', '#4A809C', '#68A6AD', '#9EC8B9', '#F0D8A8']
sns.countplot(data=df, x='device', palette=colors)
plt.title("Devies distribution across the users")
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_2710/2308333455.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='device', palette=colors)

# %%
sns.countplot(data=df, x = 'gender', palette=['Orange', 'Pink', 'Blue'])
plt.title("Gender distribution across the users")
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_2710/3739028548.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x = 'gender', palette=['Orange', 'Pink', 'Blue'])

# %%
from matplotlib.axis import YAxis
age = df['age']
age.plot(kind='hist', bins=10, color='red', edgecolor='black', density=True)
sns.kdeplot(age, color='blue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.show()

# %%
print(age.mean())
print(age.median())
print(age.std())
# Out:
# 43.8474
# 44.0
# 15.501128031019146

# %%
sns.boxplot(x=df['age'])
plt.show()

# %%
q1 = np.percentile(age, 25)
q3 = np.percentile(age, 75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
outliers = age[(age < lower_bound) | (age > upper_bound)]
print("Outliers in age:", outliers.count())
# Out:
# Outliers in age: 0

# %%
age.min()
# Out:
# 18

# %%
age.max()
# Out:
# 70

# %%
import scipy.stats as stats

stats.probplot(age, dist='norm', plot=plt)
plt.title('Age Distribution')
plt.show()

# %%
age.skew()
# Out:
# np.float64(0.006334266359717476)

# %%
stats.probplot(age, dist='uniform', plot=plt)
plt.title('Age Distribution') # hence this is a uniform distribution.
plt.show()

# %%
df.head()
# Out:
#                             customer_id  age  gender subscription_type  \
# 0  a9b75100-82a8-427a-a208-72f24052884a   51   Other             Basic
# 1  49a5dfd9-7e69-4022-a6ad-0a1b9767fb5b   47   Other          Standard
# 2  4d71f6ce-fca9-4ff7-8afa-197ac24de14b   27  Female          Standard
# 3  d3c72c38-631b-4f9e-8a0e-de103cad1a7d   53   Other           Premium
# 4  4e265c34-103a-4dbb-9553-76c9aa47e946   56   Other          Standard
#
#    watch_hours  last_login_days   region  device  monthly_fee  churned  \
# 0        14.73               29   Africa      TV         8.99        1
# 1         0.70               19   Europe  Mobile        13.99        1
# 2        16.32               10     Asia      TV        13.99        0
# 3         4.51               12  Oceania      TV        17.99        1
# 4         1.89               13   Africa  Mobile        13.99        1
#
#   payment_method  number_of_profiles  avg_watch_time_per_day favorite_genre
# ...

# %%
hours = df['watch_hours']
hours.plot(kind='hist', bins=10, color='red', edgecolor='black', density=True)
sns.kdeplot(hours, color='blue')
plt.title('Watch Hours Distribution')
plt.xlabel('Watch Hours')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.show() # might contain some outliers

# %%
print(hours.mean())
print(hours.median())
print(hours.std())
# Out:
# 11.64945
# 8.0
# 12.014653647024184

# %%
print(hours.skew()) # quite right skewed
print(hours.kurtosis()) # heavy tails!
# Out:
# 2.2591953419514588
# 7.797026244051225

# %%
q1 = np.percentile(hours, 25)
q3 = np.percentile(hours, 75) # statistical method to detect outliers
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
outliers = hours[(hours < lower_bound) | (hours > upper_bound)]
print("Outliers in watch hours:", outliers.count())
# Out:
# Outliers in watch hours: 238

# %%
outliers.sort_values().head(10)
# Out:
# 3462    35.13
# 787     35.20
# 3142    35.22
# 2008    35.35
# 2156    35.36
# 941     35.36
# 3788    35.37
# 103     35.52
# 3262    35.52
# 1514    35.54
# Name: watch_hours, dtype: float64

# %%
hours.sort_values().tail(10)
# Out:
# 1101     81.07
# 3391     82.61
# 3036     82.63
# 3285     83.55
# 405      86.73
# 3656     89.83
# 339      92.07
# 2017     98.42
# 4544    101.06
# 3987    110.40
# Name: watch_hours, dtype: float64

# %%
df['watch_hours'].describe()
# Out:
# count    5000.000000
# mean       11.649450
# std        12.014654
# min         0.010000
# 25%         3.337500
# 50%         8.000000
# 75%        16.030000
# max       110.400000
# Name: watch_hours, dtype: float64

# %%
df.head()
# Out:
#                             customer_id  age  gender subscription_type  \
# 0  a9b75100-82a8-427a-a208-72f24052884a   51   Other             Basic
# 1  49a5dfd9-7e69-4022-a6ad-0a1b9767fb5b   47   Other          Standard
# 2  4d71f6ce-fca9-4ff7-8afa-197ac24de14b   27  Female          Standard
# 3  d3c72c38-631b-4f9e-8a0e-de103cad1a7d   53   Other           Premium
# 4  4e265c34-103a-4dbb-9553-76c9aa47e946   56   Other          Standard
#
#    watch_hours  last_login_days   region  device  monthly_fee  churned  \
# 0        14.73               29   Africa      TV         8.99        1
# 1         0.70               19   Europe  Mobile        13.99        1
# 2        16.32               10     Asia      TV        13.99        0
# 3         4.51               12  Oceania      TV        17.99        1
# 4         1.89               13   Africa  Mobile        13.99        1
#
#   payment_method  number_of_profiles  avg_watch_time_per_day favorite_genre
# ...

# %%
matching = df[df['watch_hours'] == 110.40]
matching[['watch_hours', 'avg_watch_time_per_day']]
# Out:
#       watch_hours  avg_watch_time_per_day
# 3987        110.4                    3.25

# %%
sns.boxplot(x=df['watch_hours'])
plt.show() # might be the natural distribution of the data

# %%
stats.probplot(df['watch_hours'], dist='norm', plot=plt)
plt.title('Watch Hours Distribution')
plt.show() # not normal

# %%
stats.probplot(df['watch_hours'], dist='uniform', plot=plt)
plt.title('Watch Hours Distribution')
plt.show() # not uniform too, figure indicates very strong positive shift in curve.

# %%
plt.hist(df['watch_hours'], bins=30)
plt.yscale('log')
plt.title('Watch Hours Distribution')
plt.xlabel('Watch Hours')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.show()
# follows pareto-distribution hence, a small number of users exhibit substantially higher watch hours, indicating the presence of heavy users

# %%
avg_time = df['avg_watch_time_per_day']
avg_time.head()
# Out:
# 0    0.49
# 1    0.03
# 2    1.48
# 3    0.35
# 4    0.13
# Name: avg_watch_time_per_day, dtype: float64

# %%
print(avg_time.mean())
print(avg_time.median())
print(avg_time.std())
# Out:
# 0.8748
# 0.29
# 2.619824325388844

# %%
print(avg_time.max()) # since the maximum value is near of the mean. Indicates a significant positive skew
print(avg_time.min())
# Out:
# 98.42
# 0.0

# %%
print(avg_time.skew()) # high positive skewness
print(avg_time.kurtosis()) # very heavy tails!
# Out:
# 15.83468028559404
# 447.66287216376924

# %%
plt.hist(df['avg_watch_time_per_day'], bins=30, density=True, color='red')
sns.kdeplot(avg_time, color='green')
plt.title('Average Watch Time Per Day Distribution')
plt.xlabel('Average Watch Time Per Day')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.show()

# %%
df['avg_watch_time_per_day'].sort_values().tail(10)
# Out:
# 647     25.15
# 4845    26.98
# 4285    27.27
# 3641    28.66
# 4805    29.55
# 4078    32.81
# 4792    32.88
# 2564    34.53
# 1219    52.80
# 2017    98.42
# Name: avg_watch_time_per_day, dtype: float64

# %%
df.loc[df['avg_watch_time_per_day'] > 24, ['watch_hours', 'avg_watch_time_per_day']].shape
# Out:
# (10, 2)

# %% [markdown]
# Outlier Analysis: Statistical outliers were identified in the watch_hours and avg_watch_time_per_day features using the IQR method. However, these observations were retained because there was no clear evidence that they were data entry errors, and the dataset documentation did not clearly define the calculation basis for these metrics. Removing them could eliminate genuine high-engagement user behavior.

# %%
sns.countplot(data=df, x='churned')
plt.title("Churn Distribution")
plt.xticks([0, 1], ['Not Churned', 'Churned'])
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(data=df, x='churned', y='watch_hours')
plt.title("Watch Hours Distribution by Churn")
plt.xticks([0, 1], ['Not Churned', 'Churned'])
plt.grid(axis='y')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Most churned users had watch hours in the range of approximately 2 to 10 hours, while non-churned users generally exhibited higher watch hours. This indicates that lower content consumption is associated with higher churn.

# %%
sns.boxplot(data=df, x='churned', y='age')
plt.title("Age Distribution by Churn")
plt.xticks([0, 1], ['Not Churned', 'Churned'])
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# couldn't find any significant insights

# %%
sns.boxplot(data=df, x='churned', y='last_login_days')
plt.title("Login Days Distribution by Churn")
plt.xticks([0, 1], ['Not Churned', 'Churned'])
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show() #

# %% [markdown]
# Customers who churned had significantly higher last_login_days than customers who did not churn. The median last login for churned users is approximately 41 days, compared to around 19 days for non-churned users. This indicates that prolonged inactivity is strongly associated with subscription cancellation.

# %%
sns.boxplot(data=df, x='churned', y='monthly_fee')
plt.title("Monthly Fee Distribution by Churn")
plt.xticks([0, 1], ['Not Churned', 'Churned'])
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# coudln't find significant insights

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'subscription_type', 'watch_hours',
#        'last_login_days', 'region', 'device', 'monthly_fee', 'churned',
#        'payment_method', 'number_of_profiles', 'avg_watch_time_per_day',
#        'favorite_genre'],
#       dtype='object')

# %%
sns.boxplot(data=df, x='churned', y='number_of_profiles')
plt.title("Number of Profiles Distribution by Churn")
plt.xticks([0, 1], ['Not Churned', 'Churned'])
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# couldn't find significant insights

# %%
sns.boxplot(data=df, x='churned', y='avg_watch_time_per_day')
plt.title("Average Watch Time Per Day Distribution by Churn")
plt.xticks([0, 1], ['Not Churned', 'Churned'])
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Customers who churned generally had lower average watch time per day than non-churned customers. Non-churned users also quite variability and included several high-engagement users, suggesting that higher daily engagement is associated with better customer retention.

# %% [markdown]
# ## Side bars plot for comparision with different fields with resepct to churned or not

# %%
sns.countplot(data=df, x='subscription_type', hue='churned')
plt.title("Subscription Type Distribution by Churn")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
#  Basic users have churned the most and standard/premium users have churned at the same rate. Improvement like customized ads, playlist and flexibility may help losing considerable amount of basic users. With the premium users being more loyal than basic plan users

# %%
sns.countplot(data=df, x='payment_method', hue='churned')
plt.title("Payment Method Distribution by Churn")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Users with crypto payment usually occur to leave the platform at greater rate and credit card users with the least. While the debit card users are more loyal to the platform.

# %%
sns.countplot(data=df, x='device', hue='churned')
plt.title("Device Distribution by Churn")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# couldn't draw significant insights from the graph.!

# %%
sns.countplot(data=df, x='gender', hue='churned')
plt.title("Gender Distribution by Churn")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Male users share equivalent rate of churning an staying on the platform but the female users have more churn rate than being stay on the platform.

# %%
sns.countplot(data=df, x='region', hue='churned')
plt.title("Region Distribution by Churn")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Europe and South America users churn the most, while Africa and Oceania the least with the more users at South America

# %%
sns.countplot(data=df, x='favorite_genre', hue='churned')
plt.title("Favorite Genre Distribution by Churn")
plt.xticks(rotation=45)
plt.show()
#

# %% [markdown]
# Users who consume Drama as their regular genre drop the platform at highest rate than other genre's with the least churn rate at Sci-Fi and Comedy genre.

# %% [markdown]
# ## Stacked Bar Graphs

# %%
categorical_cols = ['gender','subscription_type','region','device','payment_method','favorite_genre']
for col in categorical_cols:
    churn_rate = pd.crosstab(df[col], df['churned'], normalize='index')*100
    churn_rate.plot(kind='bar', stacked=True, figsize=(8,5))
    plt.title(f"Churn Rate by {col}")
    plt.ylabel("Percentage")
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# ## Correlation of features

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='viridis')
plt.title("Correlation Heatmap")
plt.show()

# %%
df.to_csv('cleaned.csv', index=False)
